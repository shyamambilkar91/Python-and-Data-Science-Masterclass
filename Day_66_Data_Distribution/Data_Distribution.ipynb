# %% [markdown]
# # Data Distribution

# %% [markdown]
# ## Logistic Distribution

# %% [markdown]
# 1. Logistic Distribution is used to describe growth
# 2. used extensively in Machine learning in Logistic Regression, neural Network etc.
# 3. It has three parameter:
#     1. loc - Mean, where the peak is default - 0
#     2. scale - Standard Deviation, the flatness of distribution , Default 1
#     3. size - The shape of the returned array

# %%
from numpy import random

x = random.logistic(loc= 1, scale =2, size=(2,3))
print(x)
# Out:
# [[ 0.54941147  1.61565145  1.6722247 ]
#  [ 0.39653057  9.72367933 -0.9604742 ]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.logistic(size=1000),hist=False)
plt.show()
# Out:
# C:\Users\shyam\AppData\Local\Temp\ipykernel_7816\4178204108.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.logistic(size=1000),hist=False)

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.logistic(size=1000),hist=True)
plt.show()
# Out:
# C:\Users\shyam\AppData\Local\Temp\ipykernel_7816\992433003.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.logistic(size=1000),hist=True)
